# %% [markdown]
# Buat DataFrame 2-Itemset

# %%
import pandas as pd

# Data 2-itemset
data_assoc = {
    "2-Itemset": [
        "{Mouse, Headset}",
        "{Mouse, Laptop}",
        "{Handphone, Charger}",
        "{Laptop, Headset}",
        "{Mouse, Keyboard}"
    ],
    "Frekuensi": [4, 4, 4, 3, 3],
    "Support": [0.4, 0.4, 0.4, 0.3, 0.3]
}

df_assoc = pd.DataFrame(data_assoc)

print(df_assoc)
# Out:
#               2-Itemset  Frekuensi  Support
# 0      {Mouse, Headset}          4      0.4
# 1       {Mouse, Laptop}          4      0.4
# 2  {Handphone, Charger}          4      0.4
# 3     {Laptop, Headset}          3      0.3
# 4     {Mouse, Keyboard}          3      0.3
