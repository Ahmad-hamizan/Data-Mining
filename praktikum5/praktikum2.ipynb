# %% [markdown]
# Buat DataFrame Frekuensi & Support

# %%
import pandas as pd

# Data item, frekuensi, dan support
data_freq = {
    "Item": [
        "Mouse", "Headset", "Charger", "Handphone", "Laptop",
        "Casing HP", "Flashdisk", "Keyboard", "Power Bank", "Tablet"
    ],
    "Frekuensi": [6, 5, 4, 4, 4, 2, 3, 3, 3, 2],
    "Support": [0.6, 0.5, 0.4, 0.4, 0.4, 0.2, 0.3, 0.3, 0.3, 0.2]
}

df_freq = pd.DataFrame(data_freq)

print(df_freq)
# Out:
#          Item  Frekuensi  Support
# 0       Mouse          6      0.6
# 1     Headset          5      0.5
# 2     Charger          4      0.4
# 3   Handphone          4      0.4
# 4      Laptop          4      0.4
# 5   Casing HP          2      0.2
# 6   Flashdisk          3      0.3
# 7    Keyboard          3      0.3
# 8  Power Bank          3      0.3
# 9      Tablet          2      0.2
